# %% [markdown]
# # Adição do Campo Indexação no Modelo Truncated
#
# Nesse notebook será avaliada a influência do campo 'Indexação', presente em alguns dos acórdãos do STF, na eficácia do modelo Truncated para classificação de acórdãos dentre os ramos do direito.
#
# Para isso, será carregado o modelo Truncated, já treinado com os dados das ementas de treinamento, e nele serão injetados os dados de indexação válidos e processados para que ele possa ser novamente treinado e avaliado.
#
#
# Para isso, será feito um treinamento de modelo com aproximação Truncated juntando os textos das ementas junto com os textos das indexações. Por fim é feita uma pequena avaliação do modelo baseada em métricas básicas.

# %% [markdown]
# ## Inicialização e definiçao de constantes
#
# Como uma etapa inicial, toda a inicialização do notebook será concentrada no início desse documento. Os conteúdos contidos aqui são:
#
# 1. Instalação de bibliotecas externas
# 2. Importação de biblioteca
# 3. Definição de valores constantes que podem ter seu uso replicado ao longo do notebook
# 4. Inicialização do sistema de arquivos integrado ao Google Drive

# %%
# Installation of 3rd party libraries

# !pip install transformers
# !pip install --upgrade pytorch-lightning
# Out:
# Collecting transformers
#   Downloading transformers-4.10.2-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 5.2 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 35.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.6.4)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 30.8 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting huggingface-hub>=0.0.12
#   Downloading huggingface_hub-0.0.16-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 4.1 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (21.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 34.8 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.12->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: tokenizers, sacremoses, pyyaml, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.0.16 pyyaml-5.4.1 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.10.2
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-1.4.6-py3-none-any.whl (922 kB)
#      |████████████████████████████████| 922 kB 5.2 MB/s
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (4.62.0)
# Collecting torchmetrics>=0.4.0
#   Downloading torchmetrics-0.5.1-py3-none-any.whl (282 kB)
#      |████████████████████████████████| 282 kB 47.1 MB/s
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.9.0+cu102)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (1.19.5)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (2.6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (3.7.4.3)
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 36.9 MB/s
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (5.4.1)
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning) (21.0)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2021.8.1-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 44.4 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 50.0 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.23.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning) (2.4.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (3.3.4)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.39.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (1.34.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (0.12.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (0.4.5)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (3.17.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (0.37.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning) (57.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch-lightning) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning) (4.6.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning) (3.1.1)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp37-cp37m-manylinux2014_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 45.2 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142 kB)
#      |████████████████████████████████| 142 kB 38.7 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning) (21.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning) (3.5.0)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=4b6341deec7cbc7b6e3a768f1a2c19210e403a161e6922c9163c6d76981d6bbf
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built future
# Installing collected packages: multidict, yarl, async-timeout, fsspec, aiohttp, torchmetrics, pyDeprecate, future, pytorch-lightning
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# Successfully installed aiohttp-3.7.4.post0 async-timeout-3.0.1 fsspec-2021.8.1 future-0.18.2 multidict-5.1.0 pyDeprecate-0.3.1 pytorch-lightning-1.4.6 torchmetrics-0.5.1 yarl-1.6.3

# %%
# Imports

from google.colab import drive
import pandas as pd
import numpy as np
from transformers import BertTokenizerFast as BertTokenizer, BertModel, BertForSequenceClassification, AdamW, get_cosine_schedule_with_warmup, Trainer, TrainingArguments
from enum import Enum
from typing import List
from itertools import islice
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, TensorDataset, SequentialSampler
import re
import pytorch_lightning as pl
from pytorch_lightning import seed_everything
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %%
# Constants

CONSTANTS = {
    'TRAINING_DATASET': '/content/drive/My Drive/MAC499 - Kaique e Yurick/DB/Train_Dataset.csv',
    'VALIDATION_DATASET': '/content/drive/My Drive/MAC499 - Kaique e Yurick/DB/Validation_Dataset.csv',
    'TEST_DATASET': '/content/drive/My Drive/MAC499 - Kaique e Yurick/DB/Test_Dataset.csv',
    'BERT_MODEL_NAME': 'neuralmind/bert-large-portuguese-cased',
    'SEED': 13,
    'MODEL_PATH': '/content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/saved_models/fine-tuned/truncated-2e5-0.001-0.1.bin'
}

# Hyperparameters

HYPERPARAMETERS = {
    'BATCH_SIZE': 2,
    'EPOCHS': 3,
    'MAX_NUMBER_TOKENS': 512,
    'LEARNING_RATE': 2e-5,
    'NUMBER_OF_BRANCHES': 13,
    'WEIGHT_DECAY': 0.001,
    'WARM_UP_PROPORTION': 0.3
}

# %%
# Mounting Google Drive

drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Verificar disponibilidade da GPU
#
# O próximo passo seria verificar se a GPU oferida pela Google gratuitamente como ambiente de execução do notebook está funcionando corretamente. A GPU oferece uma performance computacional maior em relação a calculos sendo executados pela CPU.

# %%
torch.cuda.empty_cache()

# If there's a GPU available...
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla K80

# %% [markdown]
# ### Reproducibilidade
#
# Para fins de reproducibilidade, podemos definir uma semente para o pytorch lightning.

# %%
seed_everything(CONSTANTS['SEED'])
# Out:
# Global seed set to 13
# 13

# %% [markdown]
# ## Carregar os dados
#
# Após as configurações iniciais, os dados são carregados da mesma forma que no notebook de criação e treinamento do modelo Truncated.
#
# Assim, nessa etapa são carregados arquivos .csv contendo os conjuntos de treinamento e de validação.

# %%
# Read the training dataset from .csv file
documents = pd.read_csv(CONSTANTS['TRAINING_DATASET'])
# Read the validation dataset from .csv file
documents_val = pd.read_csv(CONSTANTS['VALIDATION_DATASET'])

# %% [markdown]
# O objetivo desse notebook é a utilização dos dados presentes no campo 'Indexação' dos acórdãos, o que não foi feito no notebook de criação do modelo Truncated. Portanto, é preciso pré-processar os valores de indexação para poder alimentá-los ao modelo.
#
# O pré-processamento consiste de duas partes:
# primeiro é feita uma transformação dos valores de indexação em textos, a remoção de alguns caracteres especiais dos textos de indexação e uma contagem da frequência dos termos de indexação para que seja feita uma identificação de termos que são muito presentes mas que não agregam na inferência do ramo do acórdão como 'VIDE EMENTA' e 'AGUARDANDO INDEXAÇÃO'. Após isso é feita a remoção desses termos identificados e criados novos dataframes (de treino e de validação) contendo apenas os valores de indexação processados e seus respectivos valores de classificação entre os ramos.

# %%
indexes = []
for i, index in enumerate(documents['indexacao'].tolist()):
  x1 = re.sub('[\]\[\']', '', index)
  x = re.sub('[:]', ',', x1)
  if x != '':
    for tmp in x.split(','):
      indexes.append(tmp.strip())
for i, index in enumerate(documents_val['indexacao'].tolist()):
  x = re.sub('[\]\[\']', '', index)
  if x != '':
    for tmp in x.split(','):
      indexes.append(tmp.strip())

freq = {}
for item in indexes:
  if item in freq:
    freq[item] += 1
  else:
    freq[item] = 1

sorted_items = sorted(freq.items(), key=lambda x: x[1], reverse=True)
sorted_items
# Out:
# [('MIN', 3651),
#  ('AUSÊNCIA', 2747),
#  ('VIDE EMENTA', 1949),
#  ('VOTO VENCIDO', 1837),
#  ('HIPÓTESE', 1777),
#  ('DECORRÊNCIA', 1689),
#  ('FUNDAMENTAÇÃO COMPLEMENTAR', 1460),
#  ('NECESSIDADE', 1445),
#  ('IMPOSSIBILIDADE', 1358),
#  ('FUNDAMENTO', 1321),
#  ('EXISTÊNCIA', 1306),
#  ('POSSIBILIDADE', 1235),
#  ('INEXISTÊNCIA', 1184),
#  ('CARACTERIZAÇÃO', 1160),
#  ('PREVISÃO', 1063),
#  ('CONSTITUIÇÃO FEDERAL', 1006),
#  ('OCORRÊNCIA', 958),
#  ('CONFIGURAÇÃO', 941),
#  ('MARCO AURÉLIO', 904),
#  ('FINALIDADE', 885),
#  ('OFENSA', 868),
#  ('APLICAÇÃO', 813),
#  ('DECISÃO', 793),
#  ('DESCABIMENTO', 792),
#  ('SUPREMO TRIBUNAL FEDERAL (STF)', 789),
#  ('LEI', 763),
#  ('COMPETÊNCIA', 746),
#  ('ESTADO', 721),
#  ('CONCESSÃO', 646),
#  ('INOCORRÊNCIA', 603),
#  ('JULGAMENTO', 599),
#  ('ÂMBITO', 593),
#  ('CASO CONCRETO', 581),
#  ('OBJETIVO', 579),
#  ('MEMBRO', 552),
#  ('CRIME', 543),
#  ('MATÉRIA', 542),
#  ('OBSERVÂNCIA', 517),
#  ('ENTENDIMENTO', 492),
#  ('INCONSTITUCIONALIDADE', 486),
#  ('PEDIDO', 476),
#  ('MANDADO DE SEGURANÇA', 468),
#  ('CONSIDERAÇÃO', 467),
#  ('EXERCÍCIO', 459),
#  ('APRECIAÇÃO', 458),
#  ('EXIGÊNCIA', 431),
#  ('HABEAS CORPUS', 428),
#  ('RECURSO EXTRAORDINÁRIO', 425),
#  ('DIREITO', 411),
#  ('SERVIDOR PÚBLICO', 407),
#  ('PAGAMENTO', 407),
#  ('GARANTIA', 404),
#  ('FIXAÇÃO', 396),
#  ('TOTALIDADE', 392),
#  ('STF', 392),
#  ('DENÚNCIA', 392),
#  ('DETERMINAÇÃO', 387),
#  ('UTILIZAÇÃO', 387),
#  ('EXCLUSIVIDADE', 386),
#  ('DISPOSITIVO', 379),
#  ('RECONHECIMENTO', 371),
#  ('MOTIVO', 363),
#  ('MINISTÉRIO PÚBLICO', 360),
#  ('AÇÃO DIRETA DE INCONSTITUCIONALIDADE', 358),
#  ('NORMA', 351),
#  ('CRIAÇÃO', 345),
#  ('REALIZAÇÃO', 339),
#  ('MOMENTO', 338),
#  ('ATO', 336),
#  ('DIVERSIDADE', 329),
#  ('PODER JUDICIÁRIO', 328),
#  ('RECEBIMENTO', 328),
#  ('PROCESSO', 323),
#  ('EXTRADIÇÃO', 312),
#  ('VERIFICAÇÃO', 306),
#  ('ALTERAÇÃO', 300),
#  ('CABIMENTO', 298),
#  ('RECLAMAÇÃO', 293),
#  ('ATUAÇÃO', 291),
#  ('FATO', 291),
#  ('REQUISITO', 280),
#  ('VALOR', 280),
#  ('(STF)', 279),
#  ('MOMENTO ANTERIOR', 278),
#  ('DEVER', 276),
#  ('LIMITAÇÃO', 276),
#  ('DEFESA', 267),
#  ('PRAZO', 266),
#  ('ALEGAÇÃO', 266),
#  ('PRECATÓRIO', 263),
#  ('PENA', 260),
#  ('OBJETO', 259),
#  ('REFERÊNCIA', 258),
#  ('RESTRIÇÃO', 257),
#  ('PROTEÇÃO', 255),
#  ('IDENTIDADE', 255),
#  ('CONSTITUCIONALIDADE', 254),
#  ('MANUTENÇÃO', 250),
#  ('AFASTAMENTO', 249),
#  ('ATRIBUIÇÃO', 247),
#  ('PROVA', 247),
#  ('UNIÃO', 247),
#  ('DESNECESSIDADE', 244),
#  ('DEFINIÇÃO', 243),
#  ('IMPEDIMENTO', 241),
#  ('NULIDADE', 241),
#  ('DISTINÇÃO', 240),
#  ('RÉU', 239),
#  ('RESULTADO', 239),
#  ('QUESTÃO DE ORDEM', 238),
#  ('DECLARAÇÃO', 236),
#  ('IRRELEVÂNCIA', 236),
#  ('VEDAÇÃO', 235),
#  ('MÉRITO', 232),
#  ('LEI ESTADUAL', 229),
#  ('RISCO', 229),
#  ('EDIÇÃO', 226),
#  ('APOSENTADORIA', 225),
#  ('IMPROCEDÊNCIA', 224),
#  ('MUNICÍPIO', 224),
#  ('INAPLICABILIDADE', 221),
#  ('CONFORMIDADE', 221),
#  ('PRINCÍPIO', 219),
#  ('CONDUTA', 218),
#  ('PODER PÚBLICO', 218),
#  ('CONCURSO PÚBLICO', 217),
#  ('PRISÃO PREVENTIVA', 216),
#  ('FUNDAMENTAÇÃO', 215),
#  ('AÇÃO PENAL', 214),
#  ('CORRELAÇÃO', 213),
#  ('CUMPRIMENTO', 213),
#  ('OBRIGATORIEDADE', 211),
#  ('INCIDÊNCIA', 209),
#  ('VINCULAÇÃO', 208),
#  ('RECURSO', 208),
#  ('REGULAMENTAÇÃO', 208),
#  ('GILMAR MENDES', 207),
#  ('IMPUGNAÇÃO', 207),
#  ('REMUNERAÇÃO', 205),
#  ('JURISPRUDÊNCIA', 204),
#  ('CONDIÇÃO', 201),
#  ('MOMENTO POSTERIOR', 201),
#  ('DEMONSTRAÇÃO', 198),
#  ('POSTERIORIDADE', 196),
#  ('EXTENSÃO', 195),
#  ('INCLUSÃO', 195),
#  ('AUTORIZAÇÃO', 195),
#  ('LEGISLAÇÃO', 193),
#  ('PODER EXECUTIVO', 192),
#  ('LEI COMPLEMENTAR', 192),
#  ('DESCUMPRIMENTO', 192),
#  ('ADMINISTRAÇÃO PÚBLICA', 192),
#  ('TRIBUNAL', 190),
#  ('SUFICIÊNCIA', 188),
#  ('PRESERVAÇÃO', 184),
#  ('ACUSADO', 183),
#  ('DECISÃO JUDICIAL', 181),
#  ('EXTRADITANDO', 180),
#  ('PRINCÍPIO DA ISONOMIA', 180),
#  ('BENEFÍCIO', 180),
#  ('EMENDA CONSTITUCIONAL', 180),
#  ('PROVIMENTO', 180),
#  ('PRESCRIÇÃO', 179),
#  ('AUTONOMIA', 179),
#  ('VOTO', 177),
#  ('TRIBUNAL DE CONTAS DA UNIÃO (TCU)', 176),
#  ('CARGO', 176),
#  ('PROCEDÊNCIA', 176),
#  ('DIREITO FUNDAMENTAL', 175),
#  ('LEGITIMIDADE', 172),
#  ('INVIABILIDADE', 171),
#  ('SUBSTITUIÇÃO', 169),
#  ('SERVIÇO PÚBLICO', 169),
#  ('CONHECIMENTO', 169),
#  ('JUIZ', 169),
#  ('IMPOSIÇÃO', 169),
#  ('NORMA CONSTITUCIONAL', 168),
#  ('LUIZ FUX', 168),
#  ('PARTICIPAÇÃO', 168),
#  ('FORMA', 167),
#  ('EXECUÇÃO', 163),
#  ('AYRES BRITTO', 162),
#  ('CONSTITUIÇÃO FEDERAL DE 1988', 162),
#  ('MEDIDA PROVISÓRIA', 161),
#  ('CONTRARIEDADE', 160),
#  ('CONDENAÇÃO', 158),
#  ('ANTERIORIDADE', 158),
#  ('INADMISSIBILIDADE', 157),
#  ('VIOLAÇÃO', 157),
#  ('PRELIMINAR', 157),
#  ('EFICÁCIA', 156),
#  ('CELSO DE MELLO', 155),
#  ('INTERVENÇÃO FEDERAL', 155),
#  ('COMPROVAÇÃO', 154),
#  ('EXAME', 154),
#  ('SITUAÇÃO', 154),
#  ('DIFERENÇA', 152),
#  ('INDEFERIMENTO', 151),
#  ('ANULAÇÃO', 151),
#  ('EFEITO', 151),
#  ('INTERPRETAÇÃO', 150),
#  ('PRESTAÇÃO', 150),
#  ('INDEPENDÊNCIA', 149),
#  ('CRITÉRIO', 149),
#  ('(CÍVEL)', 148),
#  ('ADVOGADO', 148),
#  ('INSUFICIÊNCIA', 148),
#  ('PREJUÍZO', 148),
#  ('FUNÇÃO', 148),
#  ('ADEQUAÇÃO', 147),
#  ('LICITAÇÃO', 146),
#  ('EXCLUSÃO', 145),
#  ('SUJEIÇÃO', 144),
#  ('DECLARAÇÃO DE INCONSTITUCIONALIDADE', 144),
#  ('DEFERIMENTO', 143),
#  ('RICARDO LEWANDOWSKI', 142),
#  ('ATIVIDADE', 142),
#  ('CONTROLE', 141),
#  ('ATO ADMINISTRATIVO', 140),
#  ('SUBMISSÃO', 139),
#  ('UNIÃO FEDERAL', 139),
#  ('VALIDADE', 139),
#  ('DIREITO ADQUIRIDO', 139),
#  ('AUMENTO', 138),
#  ('CONSEQUÊNCIA', 137),
#  ('VIGÊNCIA', 136),
#  ('FAZENDA PÚBLICA', 135),
#  ('LEGISLADOR', 134),
#  ('PROCESSO ADMINISTRATIVO', 133),
#  ('DISCUSSÃO', 133),
#  ('ROBERTO BARROSO', 130),
#  ('INTERESSE', 129),
#  ('AUTOS', 128),
#  ('CEZAR PELUSO', 127),
#  ('SUSPENSÃO', 127),
#  ('CONFLITO', 127),
#  ('PARTIDO POLÍTICO', 127),
#  ('INTERVENÇÃO', 126),
#  ('APLICABILIDADE', 125),
#  ('DESCARACTERIZAÇÃO', 125),
#  ('MAGISTRADO', 124),
#  ('MANIFESTAÇÃO', 124),
#  ('GOVERNADOR', 123),
#  ('PACIENTE', 123),
#  ('TRIBUNAL DE JUSTIÇA', 123),
#  ('PROIBIÇÃO', 123),
#  ('TRIBUTO', 123),
#  ('PODER LEGISLATIVO', 122),
#  ('REGIME JURÍDICO', 122),
#  ('PROCEDIMENTO', 122),
#  ('DESTINAÇÃO', 122),
#  ('REVISÃO', 122),
#  ('IMPETRANTE', 121),
#  ('CÁRMEN LÚCIA', 121),
#  ('DIAS TOFFOLI', 120),
#  ('ABRANGÊNCIA', 119),
#  ('INSTAURAÇÃO', 119),
#  ('REGRA', 119),
#  ('CARGO PÚBLICO', 118),
#  ('DATA', 118),
#  ('NATUREZA JURÍDICA', 118),
#  ('EDSON FACHIN', 117),
#  ('REJEIÇÃO', 117),
#  ('APURAÇÃO', 116),
#  ('CONSELHO NACIONAL DE JUSTIÇA (CNJ)', 116),
#  ('PREJUDICIALIDADE', 115),
#  ('CONSTITUIÇÃO ESTADUAL', 115),
#  ('CÁLCULO', 114),
#  ('FISCALIZAÇÃO', 113),
#  ('ACESSO', 113),
#  ('PRINCÍPIO DA PROPORCIONALIDADE', 113),
#  ('INTERMÉDIO', 113),
#  ('EXCEÇÃO', 112),
#  ('PARLAMENTAR', 112),
#  ('RESSALVA DE ENTENDIMENTO', 112),
#  ('IMÓVEL', 112),
#  ('EFEITO VINCULANTE', 111),
#  ('FUNDAMENTAÇÃO DIVERSA', 111),
#  ('COISA JULGADA', 111),
#  ('DECRETAÇÃO', 111),
#  ('CANDIDATO', 111),
#  ('SUPREMO TRIBUNAL FEDERAL', 110),
#  ('IGUALDADE', 110),
#  ('DESPROVIMENTO', 110),
#  ('ATENDIMENTO', 110),
#  ('LIMINAR', 109),
#  ('AUTORIDADE', 109),
#  ('DISPOSITIVO CONSTITUCIONAL', 109),
#  ('INDICAÇÃO', 108),
#  ('SERVIÇO', 108),
#  ('OBTENÇÃO', 108),
#  ('EXCEPCIONALIDADE', 107),
#  ('OBITER DICTUM', 107),
#  ('PROSSEGUIMENTO', 106),
#  ('REDUÇÃO', 106),
#  ('CRÉDITO', 106),
#  ('BASE', 106),
#  ('REGISTRO', 105),
#  ('PRINCÍPIO CONSTITUCIONAL', 105),
#  ('PREENCHIMENTO', 103),
#  ('PERMANÊNCIA', 103),
#  ('COBRANÇA', 103),
#  ('PRINCÍPIO DA PRESUNÇÃO DE INOCÊNCIA', 103),
#  ('LEGALIDADE', 102),
#  ('NOMEAÇÃO', 102),
#  ('ADMISSIBILIDADE', 101),
#  ('CONTRADITÓRIO', 101),
#  ('DELITO', 101),
#  ('PERÍODO', 100),
#  ('SUPERVENIÊNCIA', 100),
#  ('PREVALÊNCIA', 99),
#  ('INTERPOSIÇÃO', 99),
#  ('TRÂNSITO EM JULGADO', 99),
#  ('ORIGEM', 99),
#  ('INELEGIBILIDADE', 99),
#  ('DESCRIÇÃO', 98),
#  ('EQUIPARAÇÃO', 98),
#  ('EXTINÇÃO', 98),
#  ('AFERIÇÃO', 98),
#  ('RECURSO EM HABEAS CORPUS', 97),
#  ('ASSEGURAMENTO', 97),
#  ('SEGURANÇA JURÍDICA', 97),
#  ('INFORMAÇÃO', 96),
#  ('ALCANCE', 96),
#  ('PRESUNÇÃO', 96),
#  ('MODIFICAÇÃO', 96),
#  ('MODULAÇÃO DE EFEITOS', 96),
#  ('COMPETÊNCIA PRIVATIVA', 95),
#  ('PENSÃO POR MORTE', 95),
#  ('FALTA', 95),
#  ('PRISÃO', 94),
#  ('ADOÇÃO', 94),
#  ('REVOGAÇÃO', 94),
#  ('ACUSAÇÃO', 94),
#  ('PLENÁRIO', 94),
#  ('RELAÇÃO', 94),
#  ('RESOLUÇÃO', 94),
#  ('ÓRGÃO', 93),
#  ('PROPORCIONALIDADE', 93),
#  ('DEVIDO PROCESSO LEGAL', 93),
#  ('PRESIDENTE DA REPÚBLICA', 93),
#  ('PROPOSITURA', 93),
#  ('SAÚDE', 92),
#  ('MULTIPLICIDADE', 92),
#  ('JULGAMENTO CONJUNTO', 92),
#  ('EVOLUÇÃO', 92),
#  ('INÍCIO', 92),
#  ('INDÍCIO', 92),
#  ('SENTENÇA', 91),
#  ('INQUÉRITO POLICIAL', 91),
#  ('INOBSERVÂNCIA', 91),
#  ('PROCESSO PENAL', 91),
#  ('INCONSTITUCIONALIDADE FORMAL', 91),
#  ('INADEQUAÇÃO', 90),
#  ('IMUNIDADE TRIBUTÁRIA', 90),
#  ('DESAPROPRIAÇÃO', 90),
#  ('DISTRITO FEDERAL', 89),
#  ('DISCIPLINA', 89),
#  ('INSTITUIÇÃO', 89),
#  ('AÇÃO RESCISÓRIA', 89),
#  ('ROSA WEBER', 89),
#  ('PRESSUPOSTO', 89),
#  ('CONTRIBUIÇÃO PREVIDENCIÁRIA', 88),
#  ('JUSTIFICATIVA', 88),
#  ('VENCIMENTO', 88),
#  ('NÚMERO', 88),
#  ('COMPETÊNCIA LEGISLATIVA', 88),
#  ('INCOMPATIBILIDADE', 87),
#  ('OBRIGAÇÃO', 87),
#  ('ORGANIZAÇÃO', 87),
#  ('IMPETRAÇÃO', 87),
#  ('TIPO PENAL', 86),
#  ('CONGRESSO NACIONAL', 86),
#  ('EQUIVALÊNCIA', 86),
#  ('JOAQUIM BARBOSA', 86),
#  ('AJUIZAMENTO', 86),
#  ('APRESENTAÇÃO', 86),
#  ('ESCOLHA', 86),
#  ('ÓBICE', 85),
#  ('RELEVÂNCIA', 85),
#  ('INVESTIGAÇÃO CRIMINAL', 85),
#  ('AÇÃO DECLARATÓRIA DE CONSTITUCIONALIDADE', 84),
#  ('REEXAME', 84),
#  ('PRINCÍPIO DA LEGALIDADE', 84),
#  ('PROCESSO LEGISLATIVO', 84),
#  ('LIBERDADE', 83),
#  ('PRINCÍPIO DA SEGURANÇA JURÍDICA', 83),
#  ('DECRETO', 83),
#  ('DÉBITO', 83),
#  ('FRAUDE', 82),
#  ('VENCIMENTOS', 82),
#  ('ANÁLISE', 82),
#  ('PRERROGATIVA', 82),
#  ('MOTIVAÇÃO', 82),
#  ('ADMINISTRAÇÃO', 82),
#  ('EMPRESA', 82),
#  ('ILEGALIDADE', 81),
#  ('BASE DE CÁLCULO', 81),
#  ('SUPERAÇÃO', 81),
#  ('MEDIDA CAUTELAR', 81),
#  ('PARTE IMPETRANTE', 80),
#  ('SOLUÇÃO', 80),
#  ('COMETIMENTO', 80),
#  ('RAZOABILIDADE', 80),
#  ('ORDEM', 80),
#  ('ENTE FEDERADO', 79),
#  ('PRINCÍPIO DA RAZOABILIDADE', 79),
#  ('VISTORIA', 79),
#  ('LEI FEDERAL', 78),
#  ('ANTECIPAÇÃO DE TUTELA', 78),
#  ('INICIATIVA', 78),
#  ('RAZÃO', 78),
#  ('ESTADO BRASILEIRO', 78),
#  ('OMISSÃO', 78),
#  ('COMPOSIÇÃO', 78),
#  ('CIDADÃO', 78),
#  ('INVASÃO', 78),
#  ('DOLO', 78),
#  ('MINISTRO', 78),
#  ('PARCIALIDADE', 77),
#  ('GARANTIA À AMPLA DEFESA', 77),
#  ('EXCESSO', 77),
#  ('TRANSFERÊNCIA', 77),
#  ('SEPÚLVEDA PERTENCE', 77),
#  ('FAVORECIMENTO', 77),
#  ('TEORI ZAVASCKI', 77),
#  ('EXPEDIÇÃO', 77),
#  ('TESE', 77),
#  ('PROPRIEDADE', 77),
#  ('CONTRIBUINTE', 77),
#  ('ORDEM JUDICIAL', 77),
#  ('CONTRATO', 77),
#  ('VOTAÇÃO POR MAIORIA', 76),
#  ('ACÓRDÃO', 76),
#  ('PERDA', 76),
#  ('DEMOCRACIA', 76),
#  ('PENDÊNCIA', 76),
#  ('ATO NORMATIVO', 76),
#  ('LEI IMPUGNADA', 75),
#  ('PREFEITO', 75),
#  ('CORREÇÃO MONETÁRIA', 74),
#  ('COMPARAÇÃO', 74),
#  ('LIBERDADE DE EXPRESSÃO', 74),
#  ('ESTADO REQUERENTE', 74),
#  ('ORÇAMENTO', 74),
#  ('RESPONSABILIDADE', 74),
#  ('PUBLICAÇÃO', 73),
#  ('GARANTIA CONSTITUCIONAL', 73),
#  ('DANO', 73),
#  ('LEGITIMIDADE ATIVA', 73),
#  ('IMÓVEL RURAL', 73),
#  ('ESPÉCIE', 73),
#  ('TRIBUNAL PLENO', 72),
#  ('CARÁTER POLÍTICO', 72),
#  ('PRÁTICA', 72),
#  ('AUTOR', 71),
#  ('EFETIVIDADE', 71),
#  ('ESTADO DEMOCRÁTICO DE DIREITO', 71),
#  ('VÍTIMA', 71),
#  ('CONDICIONAMENTO', 71),
#  ('CONCLUSÃO', 71),
#  ('PRINCÍPIO DA SEPARAÇÃO DOS PODERES', 71),
#  ('INTERPRETAÇÃO CONFORME A CONSTITUIÇÃO', 71),
#  ('INCOMPETÊNCIA', 70),
#  ('CÓDIGO DE PROCESSO PENAL', 70),
#  ('SANÇÃO', 70),
#  ('JUÍZO', 70),
#  ('CONVERSÃO', 70),
#  ('REGULAÇÃO', 70),
#  ('INCORPORAÇÃO', 70),
#  ('CRIME DE RESPONSABILIDADE', 70),
#  ('AÇÃO', 70),
#  ('PRESIDENTE', 70),
#  ('PODER', 70),
#  ('TRIBUNAL DE CONTAS', 69),
#  ('PROLAÇÃO', 69),
#  ('PRINCÍPIO DA DIGNIDADE DA PESSOA HUMANA', 69),
#  ('AMPLA DEFESA', 69),
#  ('POSSE', 69),
#  ('INTERESSE PÚBLICO', 69),
#  ('REPRESENTAÇÃO', 69),
#  ('EXCESSO DE PRAZO', 69),
#  ('RESTITUIÇÃO', 69),
#  ('JUSTA CAUSA', 68),
#  ('DIREITO LÍQUIDO E CERTO', 68),
#  ('ADMISSÃO', 68),
#  ('SUPRESSÃO', 68),
#  ('CASSAÇÃO', 67),
#  ('INTEGRAÇÃO', 67),
#  ('DIREITO SUBJETIVO', 67),
#  ('EDUCAÇÃO', 67),
#  ('DELEGAÇÃO', 67),
#  ('IMPOSTO SOBRE CIRCULAÇÃO DE MERCADORIAS E PRESTAÇÃO DE SERVIÇOS (ICMS)',
#   67),
#  ('TEMPO', 66),
#  ('LEI ORDINÁRIA', 66),
#  ('INEXIGIBILIDADE', 66),
#  ('COMPENSAÇÃO', 66),
#  ('VIABILIZAÇÃO', 66),
#  ('INTEGRALIDADE', 66),
#  ('TAXA', 66),
#  ('COMPATIBILIDADE', 65),
#  ('SUPERIOR TRIBUNAL DE JUSTIÇA (STJ)', 65),
#  ('EROS GRAU', 65),
#  ('FORMAÇÃO', 65),
#  ('AMPLIAÇÃO', 65),
#  ('SUPERIORIDADE', 65),
#  ('ALEXANDRE DE MORAES', 65),
#  ('VÍCIO', 64),
#  ('AGUARDANDO INDEXAÇÃO', 64),
#  ('SENTENÇA CONDENATÓRIA', 64),
#  ('ORDENAMENTO JURÍDICO BRASILEIRO', 63),
#  ('INSTITUTO', 63),
#  ('DEVOLUÇÃO', 63),
#  ('SÚMULA', 63),
#  ('DOUTRINA', 63),
#  ('ARGUIÇÃO DE DESCUMPRIMENTO DE PRECEITO FUNDAMENTAL', 62),
#  ('COMUNICAÇÃO', 62),
#  ('PROFERIMENTO', 62),
#  ('PRERROGATIVA DE FORO', 62),
#  ('RECOLHIMENTO', 62),
#  ('MODALIDADE', 61),
#  ('PRINCÍPIO DA MORALIDADE', 61),
#  ('DESRESPEITO', 61),
#  ('PROCURADOR', 61),
#  ('APROVAÇÃO', 61),
#  ('REGIMENTO INTERNO', 61),
#  ('IMPUTAÇÃO', 61),
#  ('INSTITUTO JURÍDICO', 61),
#  ('AÇÃO JUDICIAL', 61),
#  ('RELAÇÃO JURÍDICA', 61),
#  ('CHEFE DO PODER EXECUTIVO', 61),
#  ('ATIVIDADE ECONÔMICA', 61),
#  ('INTERFERÊNCIA', 60),
#  ('SEDE', 60),
#  ('IRREGULARIDADE', 60),
#  ('INDENIZAÇÃO', 60),
#  ('ÍNDICE', 60),
#  ('PERTINÊNCIA TEMÁTICA', 60),
#  ('FÉ', 60),
#  ('AVALIAÇÃO', 60),
#  ('SEGURANÇA', 60),
#  ('OPÇÃO', 60),
#  ('PATRIMÔNIO', 60),
#  ('EDITAL', 60),
#  ('CONTRATAÇÃO', 60),
#  ('PRINCÍPIO REPUBLICANO', 60),
#  ('VANTAGEM PECUNIÁRIA', 59),
#  ('CORREÇÃO', 59),
#  ('INOVAÇÃO', 59),
#  ('PROCEDIMENTO ADMINISTRATIVO', 59),
#  ('ACUMULAÇÃO', 59),
#  ('CONTINUIDADE', 59),
#  ('AQUISIÇÃO', 59),
#  ('REMESSA', 58),
#  ('TESTEMUNHA', 58),
#  ('DENEGAÇÃO', 58),
#  ('REPERCUSSÃO GERAL', 58),
#  ('OFERECIMENTO', 58),
#  ('COMPLEMENTAÇÃO', 58),
#  ('(TCU)', 58),
#  ('PRISÃO CAUTELAR', 58),
#  ('BENEFÍCIO PREVIDENCIÁRIO', 58),
#  ('FATO GERADOR', 58),
#  ('TRIBUTAÇÃO', 58),
#  ('ARTIGO', 57),
#  ('PRAZO PRESCRICIONAL', 57),
#  ('JUSTIÇA DO TRABALHO', 57),
#  ('ELEMENTO SUBJETIVO', 57),
#  ('TRABALHADOR', 57),
#  ('ELEIÇÃO', 57),
#  ('ELLEN GRACIE', 56),
#  ('CÓDIGO PENAL', 56),
#  ('ELABORAÇÃO', 56),
#  ('SERVIDOR', 56),
#  ('ÁREA', 56),
#  ('CONCEITO', 56),
#  ('DECADÊNCIA', 56),
#  ('ANTECIPAÇÃO', 56),
#  ('USO', 55),
#  ('ÂMBITO PENAL', 55),
#  ('CLASSIFICAÇÃO', 55),
#  ('REGIME', 55),
#  ('CARREIRA', 55),
#  ('CARGO EM COMISSÃO', 55),
#  ('VANTAGEM INDEVIDA', 55),
#  ('VERBA', 55),
#  ('TERCEIRO', 55),
#  ('CÂMARA DOS DEPUTADOS', 55),
#  ('HABEAS CORPUS DE OFÍCIO', 54),
#  ('INSTRUÇÃO CRIMINAL', 54),
#  ('ENVOLVIMENTO', 54),
#  ('CONTRIBUIÇÃO SOCIAL', 54),
#  ('NOVIDADE', 54),
#  ('TITULARIDADE', 54),
#  ('ASSOCIAÇÃO', 54),
#  ('SISTEMA', 54),
#  ('ESTABELECIMENTO', 54),
#  ('DISCRICIONARIEDADE', 54),
#  ('PRINCÍPIO DA INSIGNIFICÂNCIA', 54),
#  ('NORMA GERAL', 53),
#  ('PERSECUÇÃO PENAL', 53),
#  ('PROVENTO', 53),
#  ('ATO IMPUGNADO', 53),
#  ('COMPETÊNCIA ORIGINÁRIA', 53),
#  ('IMPOSTO', 53),
#  ('NOTIFICAÇÃO', 53),
#  ('CONSEQÜÊNCIA', 53),
#  ('PRETERIÇÃO', 53),
#  ('PROCESSAMENTO', 53),
#  ('CRIME DE LAVAGEM DE DINHEIRO', 53),
#  ('COMPETÊNCIA CONCORRENTE', 52),
#  ('DIREITO PENAL', 52),
#  ('PORTARIA', 52),
#  ('SIGILO', 52),
#  ('TITULAR', 52),
#  ('DENUNCIADO', 52),
#  ('PLURALIDADE', 52),
#  ('TERMO(S) DE RESGATE', 52),
#  ('INSUBSISTÊNCIA', 52),
#  ('LEI MUNICIPAL', 52),
#  ('DEFENSORIA PÚBLICA', 52),
#  ('DESAPOSENTAÇÃO', 52),
#  ('PRINCÍPIO DO CONTRADITÓRIO', 51),
#  ('TERMO INICIAL', 51),
#  ('REAJUSTE', 51),
#  ('PARTICULAR', 51),
#  ('EMPRESA PÚBLICA', 51),
#  ('FUNCIONAMENTO', 51),
#  ('NEGATIVA', 51),
#  ('QUANTIDADE', 51),
#  ('DEPUTADO FEDERAL', 51),
#  ('INQUÉRITO', 51),
#  ('PROPRIETÁRIO', 51),
#  ('SUSTENTAÇÃO ORAL', 51),
#  ('DESPESA', 50),
#  ('MEIO AMBIENTE', 50),
#  ('PRINCÍPIO DA IMPESSOALIDADE', 50),
#  ('LIBERDADE DE LOCOMOÇÃO', 50),
#  ('PRETENSÃO', 50),
#  ('DEMISSÃO', 50),
#  ('REQUERIMENTO', 50),
#  ('TRABALHO', 50),
#  ('PROMOÇÃO', 50),
#  ('(ADI)', 50),
#  ('PARTE PROCESSUAL', 50),
#  ('PESSOA JURÍDICA', 50),
#  ('CADA', 50),
#  ('REFORMA AGRÁRIA', 50),
#  ('CINCO ANOS', 50),
#  ('PRIVILÉGIO', 50),
#  ('ENTIDADE', 50),
#  ('DEPÓSITO', 50),
#  ('OBSTÁCULO', 50),
#  ('OBEDIÊNCIA', 50),
#  ('CONSUMAÇÃO', 50),
#  ('AUTARQUIA', 50),
#  ('IMPROBIDADE ADMINISTRATIVA', 50),
#  ('HIERARQUIA', 49),
#  ('PESSOA NATURAL', 49),
#  ('LEI NOVA', 49),
#  ('CHEFE', 49),
#  ('VÍNCULO', 49),
#  ('SALÁRIO', 49),
#  ('EMPREGADO', 49),
#  ('UNICIDADE', 49),
#  ('CORRÉU', 49),
#  ('INVOCAÇÃO', 49),
#  ('DISTRIBUIÇÃO', 49),
#  ('DECISÃO MONOCRÁTICA', 49),
#  ('TRIBUNAL SUPERIOR ELEITORAL (TSE)', 49),
#  ('AÇÃO CIVIL PÚBLICA', 49),
#  ('AGENTE', 48),
#  ('ABUSO', 48),
#  ('SOCIEDADE', 48),
#  ('EXPRESSÃO', 48),
#  ('RECURSO FINANCEIRO', 48),
#  ('RENÚNCIA', 48),
#  ('CONTROLE ABSTRATO', 48),
#  ('TUTELA ANTECIPADA', 48),
#  ('JURISDIÇÃO', 48),
#  ('FAMÍLIA', 48),
#  ('CARÁTER', 48),
#  ('SEQÜESTRO', 48),
#  ('DIREITO COMPARADO', 48),
#  ('PRECEDENTE', 48),
#  ('MANDATO', 48),
#  ('INTERESSADO', 48),
#  ('DISCRIMINAÇÃO', 47),
#  ('CONTROLE DE CONSTITUCIONALIDADE', 47),
#  ('ACÓRDÃO RECORRIDO', 47),
#  ('PREQUESTIONAMENTO', 47),
#  ('LEI PENAL', 47),
#  ('TEXTO CONSTITUCIONAL', 47),
#  ('ISENÇÃO', 47),
#  ('DURAÇÃO', 47),
#  ('RENOVAÇÃO', 47),
#  ('INTIMAÇÃO', 47),
#  ('DOCUMENTO', 47),
#  ('ARRECADAÇÃO', 47),
#  ('QUESTÃO', 47),
#  ('PRESO', 47),
#  ('PRESENÇA', 47),
#  ('ÔNUS', 47),
#  ('NATUREZA', 46),
#  ('TETO REMUNERATÓRIO', 46),
#  ('IMUNIDADE', 46),
#  ('PROJETO DE LEI', 46),
#  ('PROCESSO DE EXTRADIÇÃO', 46),
#  ('SOCIEDADE DE ECONOMIA MISTA', 46),
#  ('VONTADE', 46),
#  ('IMPUTAÇÃO DE CRIME', 46),
#  ('"HABEAS CORPUS"', 46),
#  ('IMUNIDADE PARLAMENTAR MATERIAL', 46),
#  ('CONTRIBUIÇÃO', 46),
#  ('ESTADO ESTRANGEIRO', 46),
#  ('ENTREGA', 46),
#  ('DOSIMETRIA DA PENA', 46),
#  ('PROCESSO ADMINISTRATIVO DISCIPLINAR', 46),
#  ('DEPENDÊNCIA', 45),
#  ('PRODUÇÃO', 45),
#  ('MATÉRIA INFRACONSTITUCIONAL', 45),
#  ('PRECLUSÃO', 45),
#  ('INDISPENSABILIDADE', 45),
#  ('MAGISTRATURA', 45),
#  ('PARÂMETRO', 45),
#  ('ÂMBITO FEDERAL', 45),
#  ('ORDEM PÚBLICA', 45),
#  ('APELAÇÃO', 45),
#  ('ASSEMBLÉIA LEGISLATIVA', 44),
#  ('LOCAL', 44),
#  ('COMPETÊNCIA EXCLUSIVA', 44),
#  ('CAUSA', 44),
#  ('CONCRETIZAÇÃO', 44),
#  ('OPERAÇÃO', 44),
#  ('INGRESSO', 44),
#  ('SITUAÇÃO JURÍDICA', 44),
#  ('AUTORIZAÇÃO PRÉVIA', 44),
#  ('ARQUIVAMENTO', 44),
#  ('RENDA', 44),
#  ('PARTE', 44),
#  ('RETORNO', 43),
#  ('CONSTRANGIMENTO ILEGAL', 43),
#  ('IMPLICAÇÃO', 43),
#  ('MATÉRIA CONSTITUCIONAL', 43),
#  ('VÍCIO FORMAL', 43),
#  ('VAGA', 43),
#  ('MUDANÇA', 43),
#  ('COMPROMETIMENTO', 43),
#  ('PRINCÍPIO FEDERATIVO', 43),
#  ('PENSÃO', 43),
#  ('REQUISIÇÃO', 43),
#  ('RECEPÇÃO', 43),
#  ('DIREITO PÚBLICO', 43),
#  ('CASO', 43),
#  ('AUTORIA DO CRIME', 43),
#  ('LUCRO', 43),
#  ('INVESTIDURA', 43),
#  ('ABERTURA', 43),
#  ('SEGURANÇA PÚBLICA', 43),
#  ('LEGISLAÇÃO BRASILEIRA', 42),
#  ('QUALIDADE', 42),
#  ('DECISÃO DEFINITIVA', 42),
#  ('VANTAGEM', 42),
#  ('PODER DE INVESTIGAÇÃO', 42),
#  ('CONTROLE JUDICIAL', 42),
#  ('MOEDA', 42),
#  ('INTEGRANTE', 42),
#  ('RECOMENDAÇÃO', 42),
#  ('IMPLEMENTAÇÃO', 42),
#  ('VIABILIDADE', 42),
#  ('PRINCÍPIO DA SOLIDARIEDADE', 42),
#  ('COMPLEXIDADE', 42),
#  ('CONSTITUIÇÃO', 41),
#  ('CONEXÃO', 41),
#  ('ATO JURÍDICO PERFEITO', 41),
#  ('DESCONSIDERAÇÃO', 41),
#  ('PRODUTIVIDADE', 41),
#  ('BEM', 41),
#  ('RECEITA', 41),
#  ('PRINCÍPIO DA RESERVA LEGAL', 41),
#  ('TRANSFORMAÇÃO', 41),
#  ('MANDADO DE INJUNÇÃO', 41),
#  ('LIQUIDAÇÃO', 41),
#  ('DILIGÊNCIA', 41),
#  ('PARCELA', 41),
#  ('QUEIXA', 41),
#  ('MATERIALIDADE DO FATO', 41),
#  ('LIMITE MÁXIMO', 41),
#  ('(STJ)', 41),
#  ('CULPA', 41),
#  ('ATUALIZAÇÃO', 41),
#  ('CONVÊNIO', 41),
#  ('DUPLA TIPICIDADE', 40),
#  ('RESSALVA', 40),
#  ('EXTRAPOLAÇÃO', 40),
#  ('INSERÇÃO', 40),
#  ('AGENTE PÚBLICO', 40),
#  ('TRATADO INTERNACIONAL', 40),
#  ('USURPAÇÃO', 40),
#  ('PROCESSO ELEITORAL', 40),
#  ('PENA PRIVATIVA DE LIBERDADE', 39),
#  ('ENCERRAMENTO', 39),
#  ('TÉRMINO', 39),
#  ('CONTROVÉRSIA', 39),
#  ('CAUSA DE PEDIR', 39),
#  ('OCUPAÇÃO', 39),
#  ('INICIATIVA PRIVATIVA', 39),
#  ('IMUNIDADE TRIBUTÁRIA RECÍPROCA', 39),
#  ('GERAL DA UNIÃO', 39),
#  ('DELIBERAÇÃO', 39),
#  ('TRÁFICO DE ENTORPECENTES', 39),
#  ('(ICMS)', 39),
#  ('MINISTÉRIO PÚBLICO ESTADUAL', 39),
#  ('LEI COMPLEMENTAR ESTADUAL', 39),
#  ('DESEMPENHO', 39),
#  ('INCONSTITUCIONALIDADE MATERIAL', 38),
#  ('INTERCEPTAÇÃO TELEFÔNICA', 38),
#  ('DUPLICIDADE', 38),
#  ('NATUREZA ADMINISTRATIVA', 38),
#  ('DILAÇÃO PROBATÓRIA', 38),
#  ('ACRÉSCIMO', 38),
#  ('RESPONSABILIZAÇÃO', 38),
#  ('PONDERAÇÃO', 38),
#  ('BOA', 38),
#  ('INVESTIGAÇÃO', 38),
#  ('CREDOR', 38),
#  ('ALÍQUOTA', 38),
#  ('FACULDADE', 38),
#  ('CARÁTER GERAL', 38),
#  ('MULHER', 38),
#  ('FUGA', 38),
#  ('INÉPCIA', 38),
#  ('AUTO', 37),
#  ('DECISÃO INTERLOCUTÓRIA', 37),
#  ('BRASIL', 37),
#  ('INFLAÇÃO', 37),
#  ('DISPOSIÇÃO EXPRESSA', 37),
#  ('REGIME DE PRECATÓRIO', 37),
#  ('EXPLORAÇÃO', 37),
#  ('EVOLUÇÃO HISTÓRICA', 37),
#  ('PODER DE POLÍCIA', 37),
#  ('COMPROMISSO', 37),
#  ('IMPOSTO DE RENDA (IR)', 37),
#  ('RESPONSABILIDADE OBJETIVA', 37),
#  ('AMIANTO', 37),
#  ('MILITAR', 36),
#  ('COMPULSORIEDADE', 36),
#  ('QUEBRA', 36),
#  ('DESENVOLVIMENTO', 36),
#  ('PACTO FEDERATIVO', 36),
#  ('POLÍCIA JUDICIÁRIA', 36),
#  ('DÚVIDA', 36),
#  ('CONFRONTO', 36),
#  ('CELERIDADE', 36),
#  ('PRESTAÇÃO JURISDICIONAL', 36),
#  ('EQUILÍBRIO ATUARIAL', 36),
#  ('CLÁUSULA PÉTREA', 36),
#  ('PRONUNCIAMENTO', 36),
#  ('PROCESSO OBJETIVO', 36),
#  ('ELEMENTO CONCRETO', 36),
#  ('SALÁRIO MÍNIMO', 36),
#  ('MANDATO ELETIVO', 36),
#  ('CARLOS VELLOSO', 35),
#  ('PRINCÍPIO DA SIMETRIA', 35),
#  ('FORNECIMENTO', 35),
#  ('LIMITE', 35),
#  ('ATO PROCESSUAL', 35),
#  ('DESVIO', 35),
#  ('TRANSPORTE', 35),
#  ('URGÊNCIA', 35),
#  ('ISONOMIA', 35),
#  ('SINDICATO', 35),
#  ('PRODUTO', 35),
#  ('PRINCÍPIO DO JUIZ NATURAL', 35),
#  ('REGIME PREVIDENCIÁRIO', 35),
#  ('NATUREZA ALIMENTAR', 35),
#  ('UNIÃO ESTÁVEL', 35),
#  ('BEM JURÍDICO', 35),
#  ('PERMISSÃO', 35),
#  ('JUSTIFICAÇÃO', 34),
#  ('INTERPRETAÇÃO RESTRITIVA', 34),
#  ('CONTEÚDO NORMATIVO', 34),
#  ('QUESTIONAMENTO', 34),
#  ('TRIBUNAL DO JÚRI', 34),
#  ('APROVEITAMENTO', 34),
#  ('INTERESSE SOCIAL', 34),
#  ('DIVISÃO', 34),
#  ('DISPOSIÇÃO', 34),
#  ('ARGUMENTAÇÃO', 34),
#  ('CONSTITUCIONAL', 34),
#  ('ELEMENTO OBJETIVO', 34),
#  ('EXIGIBILIDADE', 34),
#  ('DIREITOS HUMANOS', 34),
#  ('GARANTIA AO DEVIDO PROCESSO LEGAL', 34),
#  ('SUBSÍDIO', 34),
#  ('LESÃO', 34),
#  ('TUTELA', 34),
#  ('ACOLHIMENTO', 34),
#  ('ESPECIFICIDADE', 34),
#  ('RECUSA', 33),
#  ('SATISFAÇÃO', 33),
#  ('REGULARIDADE', 33),
#  ('FORMULAÇÃO', 33),
#  ('DEMARCAÇÃO', 33),
#  ('DESMEMBRAMENTO', 33),
#  ('CONVOCAÇÃO', 33),
#  ('ANISTIA', 33),
#  ('PUBLICIDADE', 33),
#  ('JUSTIÇA FEDERAL', 33),
#  ('MANDATO PARLAMENTAR', 33),
#  ('PRESCRIÇÃO DA PRETENSÃO PUNITIVA', 33),
#  ('ABSOLVIÇÃO', 33),
#  ('PRINCÍPIO DA RAZOÁVEL DURAÇÃO DO PROCESSO', 33),
#  ('TRATAMENTO JURÍDICO', 33),
#  ('EFETIVAÇÃO', 33),
#  ('AGRAVO DE INSTRUMENTO', 33),
#  ('ESPERA', 33),
#  ('CUSTEIO', 33),
#  ('ILEGITIMIDADE', 32),
#  ('SENADO FEDERAL', 32),
#  ('AGENTE POLÍTICO', 32),
#  ('IDEIA', 32),
#  ('BENEFÍCIO FISCAL', 32),
#  ('MEIO', 32),
#  ('ADCT', 32),
#  ('CONSTITUIÇÃO ATUAL', 32),
#  ('CARÁTER EXCEPCIONAL', 32),
#  ('DIMINUIÇÃO', 32),
#  ('DIGNIDADE DA PESSOA HUMANA', 32),
#  ('SÚMULA VINCULANTE', 32),
#  ('CRIME HEDIONDO', 32),
#  ('PRESTAÇÃO DE SERVIÇO', 32),
#  ('ÂMBITO INTERNACIONAL', 32),
#  ('COLABORAÇÃO PREMIADA', 32),
#  ('DEPOIMENTO', 32),
#  ('AUTORIA', 32),
#  ('PETIÇÃO INICIAL', 32),
#  ('PROPRIEDADE RURAL', 31),
#  ('REITERAÇÃO', 31),
#  ('ATO DECISÓRIO', 31),
#  ('PRINCÍPIO DA SUBSIDIARIEDADE', 31),
#  ('TRIBUNAL DE CONTAS DA UNIÃO', 31),
#  ('CASA LEGISLATIVA', 31),
#  ('CULPABILIDADE', 31),
#  ('PECULATO', 31),
#  ('INVESTIGADO', 31),
#  ('EXTINÇÃO DA PUNIBILIDADE', 31),
#  ('TRÂNSITO', 31),
#  ('TCU', 31),
#  ('CORRESPONDÊNCIA', 31),
#  ('SUPREMACIA', 31),
#  ('SUPRESSÃO DE INSTÂNCIA', 31),
#  ('ATIPICIDADE', 31),
#  ('VEREADOR', 31),
#  ('ELEITOR', 31),
#  ('ACOMPANHAMENTO', 31),
#  ('PERCENTUAL', 31),
#  ('SESSÃO DE JULGAMENTO', 31),
#  ('MORALIDADE', 31),
#  ('REGIME GERAL DE PREVIDÊNCIA SOCIAL (RGPS)', 31),
#  ('PREVIDÊNCIA SOCIAL', 30),
#  ('VENDA', 30),
#  ('GRAVIDADE', 30),
#  ('DADO', 30),
#  ('INTERRUPÇÃO', 30),
#  ('ADMINISTRADOR', 30),
#  ('ADVOCACIA', 30),
#  ('PERICULOSIDADE', 30),
#  ('CONSTATAÇÃO', 30),
#  ('ESTATUTO', 30),
#  ('DECISÃO RESCINDENDA', 30),
#  ('ADMINISTRADOR PÚBLICO', 30),
#  ('ACESSO À JUSTIÇA', 30),
#  ('EXAURIMENTO', 30),
#  ('ÂMBITO NACIONAL', 30),
#  ('DIVULGAÇÃO', 30),
#  ('MENEZES DIREITO', 30),
#  ('CONTROLE CONCENTRADO', 30),
#  ('INADIMPLEMENTO', 30),
#  ('CADERNETA DE POUPANÇA', 30),
#  ('LEI DISTRITAL', 30),
#  ('ORGANIZAÇÃO CRIMINOSA', 30),
#  ('EMISSÃO', 30),
#  ('DECISÃO RECLAMADA', 30),
#  ('(ADCT)', 30),
#  ('ALARGAMENTO', 30),
#  ('IMUNIDADE PARLAMENTAR', 30),
#  ('INFLUÊNCIA', 30),
#  ('CORRUPÇÃO PASSIVA', 30),
#  ('ORDENAMENTO JURÍDICO', 30),
#  ('MECANISMO', 30),
#  ('LEGISLADOR ORDINÁRIO', 30),
#  ('PARTE RECORRENTE', 30),
#  ('INVALIDADE', 30),
#  ('POPULAÇÃO', 30),
#  ('DESCONHECIMENTO', 30),
#  ('MINORIA', 30),
#  ('CONTROLE EXTERNO', 29),
#  ('CONTAGEM', 29),
#  ('PRINCÍPIO DA IRRETROATIVIDADE DA LEI', 29),
#  ...]

# %% [markdown]
# Visualizando a lista de termos e suas frequências, é necessário fazer a remoção de uma lista relativamente extensa de termos dos textos da indexacao.

# %%
# Process the indexação column
ramos = []
indexes = []
for i, index in enumerate(documents['indexacao'].tolist()):
  x = re.sub('[\]\[\']', '', index)
  x = x.replace('VIDE EMENTA', '').replace('AGUARDANDO INDEXAÇÃO', '') \
    .replace('MIN', '').replace('VOTO VENCIDO', '') \
    .replace('SUPREMO TRIBUNAL FEDERAL (STF)', '') \
    .replace('STF', '') \
    .replace('DIREITO', '') \
    .replace('(STF)', '') \
    .replace('MARCO AURÉLIO', '') \
    .replace('QUESTÃO DE ORDEM: VOTO VENCIDO', '') \
    .replace('GILMAR MENDES', '') \
    .replace('LUIZ FUX', '') \
    .replace('AYRES BRITTO', '') \
    .replace('CELSO DE MELLO', '') \
    .replace('RICARDO LEWANDOWSKI', '') \
    .replace('ROBERTO BARROSO', '') \
    .replace('CEZAR PELUSO', '') \
    .replace('CARMEN LÚCIA', '') \
    .replace('DIAS TOFFOLI', '') \
    .replace('EDSON FACHIN', '') \
    .replace('ROSA WEBER', '') \
    .replace('JOAQUIM BARBOSA', '') \
    .replace('MINISTRO', '') \
    .replace('TEORI ZAVASCKI', '') \
    .replace('ALEXANDRE MORAES', '') \
    .replace('ELLEN GRACIE', '') \
    .replace('CARLOS VELLOSO', '') \
    .replace(':', ',') \
    .replace(', ,', ',') 
  x1 = re.sub('^, ,', '', x)
  if x1.strip() != '':
    indexes.append(x1)
    ramos.append(documents['ramo'][i])
documents_train = pd.DataFrame(list(zip(ramos, indexes)),
               columns = ['ramo', 'text'])
for row in documents.iterrows():
  tmp = pd.DataFrame({'ramo': [row[1].ramo], 'text': [row[1].ementa]})
  documents_train = pd.concat([documents_train, tmp], ignore_index = True, axis = 0)
documents_train
# Out:
#       ramo                                               text
# 0        1  AUSÊNCIA, DECADÊNCIA ADISTRATIVA, ATO, APOSENT...
# 1        1  OCORRÊNCIA, CASO CONCRETO, AUMENTO, REMUNERAÇÃ...
# 2        1  CONSTITUCIONALIDADE, DISPOSITIVO, LEI ORGÂNICA...
# 3        1  DECLARAÇÃO, INCONSTITUCIONALIDADE, LEI ESTADUA...
# 4        0  NECESSIDADE, FUNDAMENTAÇÃO IDÔNEA, RECUSA, SUB...
# ...    ...                                                ...
# 6555     2  EMENTA Recurso extraordinário – Emenda Constit...
# 6556     1  EMENTA: MANDADO DE SEGURANÇA. DECRETO HOMOLOGA...
# 6557     0  EMENTA: RECURSO ORDINÁRIO EM HABEAS-CORPUS. PR...
# 6558     1  Ementa: DIREITO CONSTITUCIONAL E ADMINISTRATIV...
# 6559     9  EMENTA: EXTRADIÇÃO. Tratado extradicional. Ine...
#
# [6560 rows x 2 columns]

# %%
# Process the indexação column on validation dataset
ramos_val = []
indexes_val = []
for i, index in enumerate(documents_val['indexacao'].tolist()):
  x = re.sub('[\]\[\']', '', index)
  x = x.replace('VIDE EMENTA', '').replace('AGUARDANDO INDEXAÇÃO', '') \
    .replace('MIN', '').replace('VOTO VENCIDO', '') \
    .replace('SUPREMO TRIBUNAL FEDERAL (STF)', '') \
    .replace('STF', '') \
    .replace('DIREITO', '') \
    .replace('(STF)', '') \
    .replace('MARCO AURÉLIO', '') \
    .replace('QUESTÃO DE ORDEM: VOTO VENCIDO', '') \
    .replace('GILMAR MENDES', '') \
    .replace('LUIZ FUX', '') \
    .replace('AYRES BRITTO', '') \
    .replace('CELSO DE MELLO', '') \
    .replace('RICARDO LEWANDOWSKI', '') \
    .replace('ROBERTO BARROSO', '') \
    .replace('CEZAR PELUSO', '') \
    .replace('CARMEN LÚCIA', '') \
    .replace('DIAS TOFFOLI', '') \
    .replace('EDSON FACHIN', '') \
    .replace('ROSA WEBER', '') \
    .replace('JOAQUIM BARBOSA', '') \
    .replace('MINISTRO', '') \
    .replace('TEORI ZAVASCKI', '') \
    .replace('ALEXANDRE MORAES', '') \
    .replace('ELLEN GRACIE', '') \
    .replace('CARLOS VELLOSO', '') \
    .replace(':', ',') \
    .replace(', ,', ',')
  x1 = re.sub('^, ,', '', x)
  if x1 != '':
    indexes_val.append(x1)
    ramos_val.append(documents_val['ramo'][i])
documents_validation = pd.DataFrame(list(zip(ramos_val, indexes_val)),
               columns = ['ramo', 'text'])
for row in documents_val.iterrows():
  tmp = pd.DataFrame({'ramo': [row[1].ramo], 'text': [row[1].ementa]})
  documents_validation = pd.concat([documents_validation, tmp], ignore_index = True, axis = 0)
documents_validation
# Out:
#       ramo                                               text
# 0        4  DESEMBARGADOR, PREENCHIMENTO, REQUISITOS, CONC...
# 1        0         ADMISSÃO, IMPETRAÇÃO, INDEFERIMENTO, ORDEM
# 2        9  INSUBSISTÊNCIA, ALEGAÇÃO, OFENSA, PRINCÍPIO DO...
# 3        0                                          (CRIAL),
# 4        1  SOLUÇÃO, PROBLEMA, TRANSIÇÃO, MODELO CONSTITUC...
# ...    ...                                                ...
# 1405     0  EMENTA: PENAL E PROCESSUAL PENAL. RECURSO ORDI...
# 1406     1  Ementa: CONSTITUCIONAL E ADMINISTRATIVO. MANDA...
# 1407     1  Ementa: DIREITO CONSTITUCIONAL. ADI. VINCULAÇÃ...
# 1408     0  Ementa: PETIÇÃO. AGRAVO REGIMENTAL. DENÚNCIA. ...
# 1409     0  Ementa: PENAL E PROCESSUAL PENAL. RECURSO ORDI...
#
# [1410 rows x 2 columns]

# %% [markdown]
# O treinamento do modelo nesse notebook segue o mesmo formato do notebook de criação do modelo Truncated. Então é baixado o tokenizer e são definidas e criadas classes para Dataset, DataModule e pro modelo em si.
#
# Por fim, o modelo Truncated é carregado do Drive e é feito o treinamento novamente utilizando o dataframe contendo as indexações como input.

# %%
class LawDocumentDataset(Dataset):
  def __init__(self, dataframe: pd.DataFrame, tokenizer: BertTokenizer, max_token_length: int=512):
    self.dataframe = dataframe
    self.tokenizer = tokenizer
    self.max_token_length = max_token_length

  def __len__(self):
    return len(self.dataframe)

  def __getitem__(self, index: int):
    row = self.dataframe.iloc[index]
    summary_document = row.text
    law_branch_id = row.ramo

    encoding = self.tokenizer.encode_plus(
      summary_document,
      add_special_tokens=True,          # Add `[CLS]` and `[SEP]`
      max_length=self.max_token_length,
      return_token_type_ids=False,
      padding="max_length",
      truncation=True,                  # Truncate encoding to the max length
      return_attention_mask=True,       # Return attention mask
      return_tensors="pt"               # Return PyTorch tensor
    )

    labels = np.eye(HYPERPARAMETERS['NUMBER_OF_BRANCHES'])[law_branch_id]  # Return a list with zeros, except for index law_branch_id that assumes one

    return dict(
        summary_document=summary_document,
        input_ids=encoding["input_ids"].flatten(),
        attention_mask=encoding["attention_mask"].flatten(),
        labels=torch.FloatTensor(labels)
    )

# %%
tokenizer = BertTokenizer.from_pretrained(CONSTANTS['BERT_MODEL_NAME'])
# Out:
# Downloading:   0%|          | 0.00/210k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/155 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/648 [00:00<?, ?B/s]

# %%
train_dataset = LawDocumentDataset(documents_train, tokenizer, HYPERPARAMETERS['MAX_NUMBER_TOKENS'])
validation_dataset = LawDocumentDataset(documents_validation, tokenizer, HYPERPARAMETERS['MAX_NUMBER_TOKENS'])

# %%
class LawDocumentClassifier(pl.LightningModule):
    
    def __init__(self, number_classes: int, steps_per_epoch: int=None, epochs: int=None, learning_rate: float=2e-5, weight_decay: float=0.01, warm_up_proportion: float=0.1):
        super().__init__()
        
        self.model = BertForSequenceClassification.from_pretrained(
            "neuralmind/bert-large-portuguese-cased",
            num_labels=number_classes,                      # The number of output labels--2 for binary classification
            output_attentions=False,                        # Returns attention weights
            output_hidden_states=False                      # Returns all hidden states
        )
        self.steps_per_epoch = steps_per_epoch
        self.epochs = epochs
        self.learning_rate = learning_rate
        self.warm_up_proportion = warm_up_proportion
        self.weight_decay = weight_decay
        
    def forward(self, input_ids, attention_mask, labels=None):
        output = self.model(input_ids,
                            attention_mask=attention_mask,
                            labels=labels,
                            return_dict=True)
        
        return output.loss, output.logits
        
    def training_step(self, batch, batch_index):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        labels = batch["labels"]
        
        loss, outputs = self(input_ids, attention_mask, labels)
        
        self.log("train_loss", loss, prog_bar=True, logger=True)
        
        return {"loss": loss, "predictions": outputs, "labels": labels}

    def compute_metrics(self, eval_pred):
        logits, labels = eval_pred
        
        classification_predictions = self.convert_to_classification_labels(logits)
        classification_labels = self.convert_to_classification_labels(labels)

        metrics = {
            "validation_accuracy": accuracy_score(classification_labels, classification_predictions),
            "validation_precision": precision_score(classification_labels, classification_predictions, average='weighted'),
            "validation_recall": recall_score(classification_labels, classification_predictions, average='weighted'),
            "validation_f1": f1_score(classification_labels, classification_predictions, average='weighted'),
        }

        return metrics
            
    def configure_optimizers(self):
        optimizer = AdamW(self.parameters(), lr=self.learning_rate, weight_decay=self.weight_decay)
        warmup_steps = self.steps_per_epoch * self.warm_up_proportion
        total_steps = self.steps_per_epoch * self.epochs - warmup_steps

        scheduler = get_cosine_schedule_with_warmup(optimizer, warmup_steps, total_steps)
        
        return (optimizer, scheduler)

    def convert_to_classification_labels(self, classifications):
        formatted_classifications = []

        for classification in classifications:
            formatted_classifications.append(np.argmax(classification).flatten())

        return formatted_classifications

# %%
model = LawDocumentClassifier(
    HYPERPARAMETERS['NUMBER_OF_BRANCHES'],
    steps_per_epoch=len(documents_train) // HYPERPARAMETERS['BATCH_SIZE'],
    epochs=HYPERPARAMETERS['EPOCHS'],
    learning_rate=HYPERPARAMETERS['LEARNING_RATE'],
    weight_decay=HYPERPARAMETERS['WEIGHT_DECAY'],
    warm_up_proportion=HYPERPARAMETERS['WARM_UP_PROPORTION']
)
# Out:
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at neuralmind/bert-large-portuguese-cased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at neuralmind/bert-large-portuguese-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    "/content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output",
    num_train_epochs = HYPERPARAMETERS['EPOCHS'],
    evaluation_strategy = 'epoch',
    per_device_train_batch_size = HYPERPARAMETERS['BATCH_SIZE'],
    per_device_eval_batch_size = HYPERPARAMETERS['BATCH_SIZE'],
    logging_steps = 30,
    overwrite_output_dir=True
)

trainer = Trainer(
    model=model,
    args=training_args,
    compute_metrics=model.compute_metrics,
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    optimizers=model.configure_optimizers()
)
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 6560
#   Num Epochs = 3
#   Instantaneous batch size per device = 2
#   Total train batch size (w. parallel, distributed & accumulation) = 2
#   Gradient Accumulation steps = 1
#   Total optimization steps = 9840
#     <div>
#
#       <progress value='5271' max='9840' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5271/9840 2:39:49 < 2:18:35, 0.55 it/s, Epoch 1.61/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Validation Accuracy</th>
#       <th>Validation Precision</th>
#       <th>Validation Recall</th>
#       <th>Validation F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.136100</td>
#       <td>0.094713</td>
#       <td>0.781560</td>
#       <td>0.743733</td>
#       <td>0.781560</td>
#       <td>0.758035</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-500
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-1000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-1500
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-2000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-2500
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-3000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 1410
#   Batch size = 2
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-3500
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-4000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-4500
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-5000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
#     <div>
#
#       <progress value='9840' max='9840' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9840/9840 5:03:57, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Validation Accuracy</th>
#       <th>Validation Precision</th>
#       <th>Validation Recall</th>
#       <th>Validation F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.136100</td>
#       <td>0.094713</td>
#       <td>0.781560</td>
#       <td>0.743733</td>
#       <td>0.781560</td>
#       <td>0.758035</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.064000</td>
#       <td>0.090236</td>
#       <td>0.800000</td>
#       <td>0.797061</td>
#       <td>0.800000</td>
#       <td>0.786975</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.070100</td>
#       <td>0.092989</td>
#       <td>0.804255</td>
#       <td>0.799941</td>
#       <td>0.804255</td>
#       <td>0.795715</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-5500
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-6000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-6500
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 1410
#   Batch size = 2
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-7000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-7500
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-8000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-8500
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-9000
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# Saving model checkpoint to /content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/indexacao_trainer_output/checkpoint-9500
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# ***** Running Evaluation *****
#   Num examples = 1410
#   Batch size = 2
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=9840, training_loss=0.10204755969163848, metrics={'train_runtime': 18239.5143, 'train_samples_per_second': 1.079, 'train_steps_per_second': 0.539, 'total_flos': 0.0, 'train_loss': 0.10204755969163848, 'epoch': 3.0})

# %%
trainer.logged_metrics
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-1fed780f2e31> in <module>()
# ----> 1 trainer.logged_metrics
#
# AttributeError: 'Trainer' object has no attribute 'logged_metrics'

# %%
torch.save(model.state_dict(), '/content/drive/My Drive/MAC499 - Kaique e Yurick/Projeto/index_truncated_model.bin')

# %% [markdown]
# ## Avaliação no Conjunto de Testes
#
# Terminada a fase de treinamento do modelo, vamos avaliá-lo com os dados do conjunto de testes para poder compará-lo com o modelo Truncated sem a adição do campo indexação.
#
# O procedimento executado é o mesmo do notebook de métricas para comparação das diferentes aproximações de construção dos modelos: o conjunto de testes é carregado do Drive e os dados são tokenizados e depois classificados pelos modelos.

# %%
test_documents = pd.read_csv(CONSTANTS['TEST_DATASET'])
test_documents.dropna(inplace=True, subset=['cod_acordao'])

# %%
# Definition of mapping from law branch name to a numeric identifier

class LawBranch(Enum):
    """Mapping to a Law Branch and an identification. The enum also stores
    the law branch name in a free text form.
    """

    Penal = (0, "Direito Penal (Direito Processual Penal)")
    Administrativo = (1, "Direito Administrativo (Licitações, Contratos Administrativos, Servidores, Desapropriação, Tribunal de Contas, Improbidade, etc.)")
    Tributario = (2, "Direito Tributário/Direito Financeiro")
    Civil = (3, "Direito Civil (Direito Comercial/Direito de Família)")
    Previdenciario = (4, "Direito Previdenciário")
    Trabalho = (5, "Direito do Trabalho")
    Processual_Civil = (6, "Direito Processual Civil")
    Eleitoral = (7, "Direito Eleitoral")
    Consumidor = (8, "Direito do Consumidor")
    Internacional = (9, "Direito Internacional (Público ou Privado)")
    Militar = (10, "Direito Militar")
    Economico = (11, "Direito Econômico (Direito concorrencial e Agências Reguladoras Setoriais, Intervenção no Domínio Econômico)")
    Ambiental = (12, "Direito Ambiental")

    def get_identifier(self) -> int:
        """Retrieves the identifier number for this instance of LawBranch.

        Returns:
            int: identifier of this instance of LawBranch
        """
        return self.value[0]
    
    @staticmethod
    def get_all_names() -> List[str]:
      """Retrieves a list of all names defined in LawBranch enum.

        Returns:
          List[str]: the list of names.

      """
      names = []
      for law_branch in LawBranch:
        names.append(law_branch.name)
      return names

# %%
# Função para tokenizar as ementas
def tokenize(ementas):
  """
    @param    ementas (list): Array de ementas a serem tokenizadas.
    @return   dataloader (torch.utils.data.DataLoader): DataLoader com os dados das predições
  """
  input_ids = []
  attention_masks = []

  for ementa in ementas:
    encoded_dict = tokenizer.encode_plus(
        ementa,
        add_special_tokens = True,
        max_length = HYPERPARAMETERS['MAX_NUMBER_TOKENS'],
        padding = 'max_length',
        truncation = True,
        return_attention_mask = True,
        return_tensors = 'pt',
        return_token_type_ids=False,
    )
        
    input_ids.append(encoded_dict['input_ids'])
    attention_masks.append(encoded_dict['attention_mask'])

  input_ids = torch.cat(input_ids, dim=0)
  attention_masks = torch.cat(attention_masks, dim=0)

  prediction_data = TensorDataset(input_ids, attention_masks)
  prediction_sampler = SequentialSampler(prediction_data)
  return DataLoader(prediction_data, sampler=prediction_sampler, batch_size=HYPERPARAMETERS['BATCH_SIZE'])


# Função que chama o modelo para classificar os acórdãos
def classify(acordaos, model):
  """
    @param  acordaos (pd.DataFrame): Dataframe com os acórdãos a serem classificados.
    @param  model (transformers.BertModel): Modelo BERT pré-treinado a ser utilizado.
    @return classifications (dict): Dicionário com os acórdãos classificados e suas ementas.
  """
  classifications = {
      'True Label': [],
      'Predicted Label': [],
      'Ementa': []
  }

  for id, row in acordaos.iterrows():
    classifications['Ementa'].append(row['ementa'])
    classifications['True Label'].append(row['ramo'])
  prediction_dataloader = tokenize(classifications['Ementa'])
  
  model.eval()
  predictions = []
  for batch in prediction_dataloader:
    batch = tuple(t.to(device) for t in batch)
    
    b_input_ids, b_input_mask = batch

    with torch.no_grad():
        _, outputs_logits = model(b_input_ids, attention_mask=b_input_mask)

    logits = outputs_logits
    logits = logits.detach().cpu().numpy()    
    predictions.append(logits)

  for prediction_batch in predictions:
    predicted_labels = np.argmax(prediction_batch, axis=1).flatten()
    for prediction in predicted_labels:
        classifications['Predicted Label'].append(prediction)

  return classifications

# %%
truncated_model = LawDocumentClassifier(HYPERPARAMETERS['NUMBER_OF_BRANCHES'], len(documents) // HYPERPARAMETERS['BATCH_SIZE'], HYPERPARAMETERS['EPOCHS'], HYPERPARAMETERS['LEARNING_RATE'])
truncated_model.load_state_dict(torch.load(CONSTANTS['MODEL_PATH']))
# Out:
# loading configuration file https://huggingface.co/neuralmind/bert-large-portuguese-cased/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/c534071830642050813fa94003dbf1234413b3f1d5dc66d259fbc82ff7d5fd59.c8340a82acfbbcd2dd960b86d2886ee120b21896ef0294150f0391918ae6ced5
# Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2",
#     "3": "LABEL_3",
#     "4": "LABEL_4",
#     "5": "LABEL_5",
#     "6": "LABEL_6",
#     "7": "LABEL_7",
#     "8": "LABEL_8",
#     "9": "LABEL_9",
#     "10": "LABEL_10",
#     "11": "LABEL_11",
#     "12": "LABEL_12"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_10": 10,
#     "LABEL_11": 11,
#     "LABEL_12": 12,
#     "LABEL_2": 2,
#     "LABEL_3": 3,
#     "LABEL_4": 4,
#     "LABEL_5": 5,
#     "LABEL_6": 6,
#     "LABEL_7": 7,
#     "LABEL_8": 8,
#     "LABEL_9": 9
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.10.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 29794
# }
#
# loading weights file https://huggingface.co/neuralmind/bert-large-portuguese-cased/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/016fb7702039667c9fb9dd2ceffaf04027b13e525a6248cda2a4a87dbb8687af.881d7200bce807f871637ac9d552c541b2d4b00146a0bf1ab0360f3640031273
# Some weights of the model checkpoint at neuralmind/bert-large-portuguese-cased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at neuralmind/bert-large-portuguese-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <All keys matched successfully>

# %%
model.cuda()
index_classifications = classify(test_documents, model)
truncated_model.cuda()
truncated_classifications = classify(test_documents, truncated_model)

# %%
print(classification_report(index_classifications['True Label'], index_classifications['Predicted Label'], target_names=LawBranch.get_all_names()))
# Out:
#                   precision    recall  f1-score   support
#
#            Penal       0.97      0.95      0.96       334
#   Administrativo       0.82      0.86      0.84       259
#       Tributario       0.70      0.70      0.70        46
#            Civil       0.38      0.25      0.30        12
#   Previdenciario       0.60      0.66      0.63        32
#         Trabalho       0.67      0.53      0.59        15
# Processual_Civil       0.51      0.50      0.51        48
#        Eleitoral       0.75      0.60      0.67         5
#       Consumidor       1.00      0.25      0.40         4
#    Internacional       0.86      0.96      0.91        53
#          Militar       0.53      0.69      0.60        13
#        Economico       0.00      0.00      0.00         3
#        Ambiental       1.00      0.60      0.75         5
#
#         accuracy                           0.84       829
#        macro avg       0.68      0.58      0.60       829
#     weighted avg       0.84      0.84      0.83       829
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(classification_report(truncated_classifications['True Label'], truncated_classifications['Predicted Label'], target_names=LawBranch.get_all_names()))
# Out:
#                   precision    recall  f1-score   support
#
#            Penal       0.97      0.94      0.95       334
#   Administrativo       0.82      0.85      0.83       259
#       Tributario       0.62      0.70      0.65        46
#            Civil       0.29      0.17      0.21        12
#   Previdenciario       0.62      0.66      0.64        32
#         Trabalho       0.46      0.40      0.43        15
# Processual_Civil       0.47      0.44      0.45        48
#        Eleitoral       0.67      0.40      0.50         5
#       Consumidor       1.00      0.25      0.40         4
#    Internacional       0.86      0.96      0.91        53
#          Militar       0.56      0.69      0.62        13
#        Economico       0.50      0.33      0.40         3
#        Ambiental       0.75      0.60      0.67         5
#
#         accuracy                           0.82       829
#        macro avg       0.66      0.57      0.59       829
#     weighted avg       0.82      0.82      0.82       829
